# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
mine = pd.read_csv("mine.csv")
mine
# Out:
#      Duration  Pulse  Maxpulse  Calories
# 0          60    110       130     409.1
# 1          60    117       145     479.0
# 2          60    103       135     340.0
# 3          45    109       175     282.4
# 4          45    117       148     406.0
# ..        ...    ...       ...       ...
# 164        60    105       140     290.8
# 165        60    110       145     300.0
# 166        60    115       145     310.2
# 167        75    120       150     320.4
# 168        75    125       150     330.4
#
# [169 rows x 4 columns]

# %%
missingRemove = mine.dropna()

# %%
df = pd.read_csv("mine.csv")
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df[["Duration"]].describe()
# Out:
#          Duration
# count  169.000000
# mean    63.846154
# std     42.299949
# min     15.000000
# 25%     45.000000
# 50%     60.000000
# 75%     60.000000
# max    300.000000

# %%
df[["Duration"]].value_counts()
# Out:
# Duration
# 60          79
# 45          35
# 30          16
# 20           9
# 90           8
# 150          4
# 120          3
# 180          3
# 15           2
# 75           2
# 160          2
# 210          2
# 25           1
# 80           1
# 270          1
# 300          1
# dtype: int64

# %%
df[["Duration"]].value_counts(normalize=True)
# Out:
# Duration
# 60          0.467456
# 45          0.207101
# 30          0.094675
# 20          0.053254
# 90          0.047337
# 150         0.023669
# 120         0.017751
# 180         0.017751
# 15          0.011834
# 75          0.011834
# 160         0.011834
# 210         0.011834
# 25          0.005917
# 80          0.005917
# 270         0.005917
# 300         0.005917
# dtype: float64

# %%
df.groupby('Pulse')[['Duration']].agg(['max','min', 'mean'])
# Out:
#       Duration
#            max  min        mean
# Pulse
# 80          30   15   22.500000
# 83          20   20   20.000000
# 85          30   30   30.000000
# 90         180   30   80.000000
# 92          60   30   50.000000
# 93          90   30   60.000000
# 95          45   20   31.666667
# 97         150   45   83.571429
# 98          90   60   65.000000
# 99          90   60   75.000000
# 100        270   45   77.368421
# 101        180   60  120.000000
# 102         60   45   57.500000
# 103         60   30   53.333333
# 104         60   45   52.500000
# 105        150   45   70.000000
# 106         60   20   50.833333
# 107        150   45   67.500000
# 108        300   45  113.571429
# 109        160   30   62.777778
# 110        160   20   66.428571
# 111         60   45   57.500000
# 112         60   30   45.000000
# 113         45   45   45.000000
# 114         60   45   56.250000
# 115         60   45   50.000000
# 116         60   60   60.000000
# ...

# %%
df.head()
# Out:
#    Duration  Pulse  Maxpulse  Calories
# 0        60    110       130     409.1
# 1        60    117       145     479.0
# 2        60    103       135     340.0
# 3        45    109       175     282.4
# 4        45    117       148     406.0

# %%
df.plot(kind='scatter', x ="Maxpulse", y="Pulse")
# Out:
# <Axes: xlabel='Maxpulse', ylabel='Pulse'>

# %%
df['Duration'].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.pivot_table(index="Duration", values="Pulse").plot(kind="box", figsize=(10, 6))
# Out:
# <Axes: >
