# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
crime = pd.read_csv('crimestat.csv')
crime
# Out:
#     Unnamed: 0             Unnamed: 1 REPORTED CASES           Unnamed: 3  \
# 0          NaN                    NaN            NaN                  NaN
# 1          NaN                    NaN   Totals Cases  Cases under Inquiry
# 2        S/No.  CASE/CRIME INCIDENCES              1                    2
# 3          NaN              HOMICIDES            NaN                  NaN
# 4            1   Death  (by shooting)            190                  117
# ..         ...                    ...            ...                  ...
# 122         98            UWA Statute            648                  112
# 123         99   Local Government Act              4                    2
# 124        100         All other Acts            821                  345
# 125        NaN  Sub Total(Other Laws)          3,006                  749
# 126        NaN            GRAND TOTAL        238,746               90,763
#
#            Unnamed: 4            Unnamed: 5                 PERFOMANCE  \
# ...

# %%
crime =crime.isnull().sum()
crime
# Out:
# Unnamed: 0                     32
# Unnamed: 1                      2
# REPORTED CASES                  2
# Unnamed: 3                      2
# Unnamed: 4                      2
# Unnamed: 5                      2
# PERFOMANCE                      2
# Unnamed: 7                      2
# Unnamed: 8                      2
# Unnamed: 9                      2
# Unnamed: 10                     2
# PERSONS TAKEN TO COURT          1
# Unnamed: 12                     3
# Unnamed: 13                     3
# Unnamed: 14                     3
# Unnamed: 15                     1
# Unnamed: 16                     3
# Unnamed: 17                     3
# Unnamed: 18                     3
# Unnamed: 19                    18
# Unnamed: 20                    18
# Unnamed: 21                    18
# SENTENCES IMPOSED BY COURTS    18
# Unnamed: 23                    19
# Unnamed: 24                    19
# Unnamed: 25                    18
# Unnamed: 26                    18
# ...

# %%
crime=crime.dropna()
crime
# Out:
#     Unnamed: 0                            Unnamed: 1 REPORTED CASES  \
# 4            1                  Death  (by shooting)            190
# 5            2                 Death (by mob action)            636
# 6            3                     Death (Poisoning)             81
# 7            4  Death (Aggravated Domestic Violence)            362
# 8            5                Death(Fire Out Breaks)             42
# ..         ...                                   ...            ...
# 120         96                          Firearms Act            109
# 121         97                            Enguli Act              4
# 122         98                           UWA Statute            648
# 123         99                  Local Government Act              4
# 124        100                        All other Acts            821
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 PERFOMANCE Unnamed: 7 Unnamed: 8  \
# 4          117         29         44         74          3          1
# ...

# %%
crime2 = crime.replace('-', '')
crime2
# Out:
#     Unnamed: 0                            Unnamed: 1 REPORTED CASES  \
# 4            1                  Death  (by shooting)            190
# 5            2                 Death (by mob action)            636
# 6            3                     Death (Poisoning)             81
# 7            4  Death (Aggravated Domestic Violence)            362
# 8            5                Death(Fire Out Breaks)             42
# ..         ...                                   ...            ...
# 120         96                          Firearms Act            109
# 121         97                            Enguli Act              4
# 122         98                           UWA Statute            648
# 123         99                  Local Government Act              4
# 124        100                        All other Acts            821
#
#     Unnamed: 3 Unnamed: 4 Unnamed: 5 PERFOMANCE Unnamed: 7 Unnamed: 8  \
# 4          117         29         44         74          3          1
# ...

# %%
for x in crime2.index:
    if crime2.loc[x,'Unnamed: 37']=='':
        crime2.drop(x, inplace= True)
crime2
# Out:
#     Unnamed: 0                                    Unnamed: 1 REPORTED CASES  \
# 12           9                                  Embezzlement            199
# 13          10                       Causing Financial losss             58
# 14          11                               Abuse of office             50
# 15          12                                Counterfeiting            541
# 16          13             Forgeries & Uttering of Documents            898
# 17          14                         Issuing False Cheques            344
# 18          15               Bank and Other Corporate Frauds             17
# 19          16                  Obtaining By False Pretences         12,313
# 20          17                       Cyber (Computer) crimes            198
# 21          18                                   Land Frauds            345
# 22          19                         Other Economic crimes            136
# ...

# %%
for x in crime2.index:
    if crime2.loc[x,'Unnamed: 8']=='':
        crime2.drop(x, inplace= True)
crime2
# Out:
#     Unnamed: 0                                    Unnamed: 1 REPORTED CASES  \
# 15          12                                Counterfeiting            541
# 16          13             Forgeries & Uttering of Documents            898
# 19          16                  Obtaining By False Pretences         12,313
# 21          18                                   Land Frauds            345
# 43          34                                    Burglaries          6,867
# 44          35                               House Breakings          3,368
# 45          36                                 Shop Breaking          2,000
# 47          38                Other Breakings (garage ,etc )          1,336
# 50          39                       Theft of Motor Vehicles          1,200
# 51          40                         Theft of Motor Cycles          4,612
# 52          41                      Theft from M/Vs (Spares)          1,093
# ...

# %%
for x in crime2.index:
    if crime2.loc[x,'Unnamed: 28']=='':
        crime2.drop(x, inplace= True)
crime2
# Out:
#     Unnamed: 0                                   Unnamed: 1 REPORTED CASES  \
# 19          16                 Obtaining By False Pretences         12,313
# 43          34                                   Burglaries          6,867
# 44          35                              House Breakings          3,368
# 45          36                                Shop Breaking          2,000
# 56          45                      Thefts of Mobile Phones          6,205
# 58          47                               Thefts of Cash          7,079
# 64          53               Theft of all  kinds (General )         31,135
# 72          59                      Simple Robbery(general)          5,173
# 83          67                              Arson (General)          2,196
# 84          68                 Malicious Damage to Property          8,339
# 90          74                           Criminal Tresspass          9,500
# ...

# %%
crime2.isnull().sum()
# Out:
# Unnamed: 0                     0
# Unnamed: 1                     0
# REPORTED CASES                 0
# Unnamed: 3                     0
# Unnamed: 4                     0
# Unnamed: 5                     0
# PERFOMANCE                     0
# Unnamed: 7                     0
# Unnamed: 8                     0
# Unnamed: 9                     0
# Unnamed: 10                    0
# PERSONS TAKEN TO COURT         0
# Unnamed: 12                    0
# Unnamed: 13                    0
# Unnamed: 14                    0
# Unnamed: 15                    0
# Unnamed: 16                    0
# Unnamed: 17                    0
# Unnamed: 18                    0
# Unnamed: 19                    0
# Unnamed: 20                    0
# Unnamed: 21                    0
# SENTENCES IMPOSED BY COURTS    0
# Unnamed: 23                    0
# Unnamed: 24                    0
# Unnamed: 25                    0
# Unnamed: 26                    0
# Unnamed: 27                    0
# ...

# %%
crime2 = crime2.duplicated().sum()
crime2
# Out:
# 0
